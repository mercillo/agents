# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %%
# Check the keys

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two trains start from the same point and travel in exactly opposite directions, one at 60 mph and the other at 90 mph, after how many hours will they be 450 miles apart? Now, if after 2 hours the second train suddenly reverses its direction and travels back towards the first train at the same speed, how long from the start will it take before the two trains are exactly 30 miles apart?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step by step.
#
# ---
#
# ### Part 1: When two trains travel in opposite directions at 60 mph and 90 mph, after how many hours will they be 450 miles apart?
#
# - Speed of Train 1, \( v_1 = 60 \) mph
# - Speed of Train 2, \( v_2 = 90 \) mph
# - Distance apart desired, \( d = 450 \) miles
#
# Since they travel in exactly opposite directions, their relative speed is:
#
# \[
# v_{\text{relative}} = v_1 + v_2 = 60 + 90 = 150 \text{ mph}
# \]
#
# Time to be 450 miles apart:
#
# \[
# t = \frac{d}{v_{\text{relative}}} = \frac{450}{150} = 3 \text{ hours}
# \]
#
# ---
#
# ### Part 2: After 2 hours, the second train reverses direction and travels back towards the first train at 90 mph. How long from the start will it take before the two trains are exactly 30 miles apart?
#
# ---
#
# #### Step 2.1: Positions after 2 hours
#
# - Distance Train 1 travels in 2 hours at 60 mph:
#
# \[
# d_1 = 60 \times 2 = 120 \text{ miles}
# \]
#
# - Distance Train 2 travels in 2 hours at 90 mph:
#
# \[
# d_2 = 90 \times 2 = 180 \text{ miles}
# \]
#
# Since they went in opposite directions from the same starting point:
#
# - Position of Train 1 after 2 hours: \( +120 \) miles from start (say, to the right)
# - Position of Train 2 after 2 hours: \( -180 \) miles from start (to the left)
#
# ---
#
# #### Step 2.2: After 2 hours, Train 2 reverses direction
#
# - From \( t = 2 \) hours onward, Train 2 moves back towards Train 1 at 90 mph.
# - Train 1 continues moving forward at 60 mph.
#
# ---
#
# #### Step 2.3: Define \( t \) as hours **after the start**, and \( x = t - 2 \) as hours after Train 2 reverses direction.
#
# At any time \( t \geq 2 \):
#
# - Position of Train 1:
#
# \[
# P_1(t) = 60 \times t
# \]
#
# - Position of Train 2 (reversing direction at \( t=2 \)):
#
# At \( t=2 \), \( P_2(2) = -180 \).
#
# From \( t=2 \), Train 2 moves towards the right at 90 mph, so for \( t \geq 2 \):
#
# \[
# P_2(t) = -180 + 90 \times (t - 2) = -180 + 90x
# \]
#
# ---
#
# #### Step 2.4: Find \( t \geq 2 \) such that distance between trains is 30 miles
#
# Distance apart:
#
# \[
# |P_1(t) - P_2(t)| = 30
# \]
#
# Substitute in terms of \( t \):
#
# \[
# |60t - (-180 + 90(t - 2))| = 30
# \]
#
# Simplify inside the absolute value:
#
# \[
# |60t + 180 - 90t + 180| = 30
# \]
#
# \[
# |(-30t) + 360| = 30
# \]
#
# Which gives two cases:
#
# 1. \(-30t + 360 = 30\)
# 2. \(-30t + 360 = -30\)
#
# ---
#
# For case 1:
#
# \[
# -30t + 360 = 30 \implies -30t = 30 - 360 = -330 \implies t = \frac{330}{30} = 11
# \]
#
# For case 2:
#
# \[
# -30t + 360 = -30 \implies -30t = -390 \implies t = \frac{390}{30} = 13
# \]
#
# Since \( t \geq 2 \), both times are valid mathematically.
#
# ---
#
# #### Step 2.5: Check feasibility in the context
#
# - At \( t=11 \) hours and \( t=13 \) hours, trains are exactly 30 miles apart.
# - At \( t=11 \), distance between trains becomes 30 miles **first** after the reversal.
# - At \( t=13 \), distance becomes 30 miles **again** (as they continue moving).
#
# ---
#
# ### **Final answers:**
#
# - **Trains 450 miles apart after:** \( \boxed{3 \text{ hours}} \)
# - **Trains 30 miles apart again after reversal at:** \( \boxed{11 \text{ hours}} \) (the first time after reversal)
#
# ---
#
# If you want, I can help you with a graph or further explanations!

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step by step.
#
# ---
#
# ### Part 1: When two trains travel in opposite directions at 60 mph and 90 mph, after how many hours will they be 450 miles apart?
#
# - Speed of Train 1, \( v_1 = 60 \) mph
# - Speed of Train 2, \( v_2 = 90 \) mph
# - Distance apart desired, \( d = 450 \) miles
#
# Since they travel in exactly opposite directions, their relative speed is:
#
# \[
# v_{\text{relative}} = v_1 + v_2 = 60 + 90 = 150 \text{ mph}
# \]
#
# Time to be 450 miles apart:
#
# \[
# t = \frac{d}{v_{\text{relative}}} = \frac{450}{150} = 3 \text{ hours}
# \]
#
# ---
#
# ### Part 2: After 2 hours, the second train reverses direction and travels back towards the first train at 90 mph. How long from the start will it take before the two trains are exactly 30 miles apart?
#
# ---
#
# #### Step 2.1: Positions after 2 hours
#
# - Distance Train 1 travels in 2 hours at 60 mph:
#
# \[
# d_1 = 60 \times 2 = 120 \text{ miles}
# \]
#
# - Distance Train 2 travels in 2 hours at 90 mph:
#
# \[
# d_2 = 90 \times 2 = 180 \text{ miles}
# \]
#
# Since they went in opposite directions from the same starting point:
#
# - Position of Train 1 after 2 hours: \( +120 \) miles from start (say, to the right)
# - Position of Train 2 after 2 hours: \( -180 \) miles from start (to the left)
#
# ---
#
# #### Step 2.2: After 2 hours, Train 2 reverses direction
#
# - From \( t = 2 \) hours onward, Train 2 moves back towards Train 1 at 90 mph.
# - Train 1 continues moving forward at 60 mph.
#
# ---
#
# #### Step 2.3: Define \( t \) as hours **after the start**, and \( x = t - 2 \) as hours after Train 2 reverses direction.
#
# At any time \( t \geq 2 \):
#
# - Position of Train 1:
#
# \[
# P_1(t) = 60 \times t
# \]
#
# - Position of Train 2 (reversing direction at \( t=2 \)):
#
# At \( t=2 \), \( P_2(2) = -180 \).
#
# From \( t=2 \), Train 2 moves towards the right at 90 mph, so for \( t \geq 2 \):
#
# \[
# P_2(t) = -180 + 90 \times (t - 2) = -180 + 90x
# \]
#
# ---
#
# #### Step 2.4: Find \( t \geq 2 \) such that distance between trains is 30 miles
#
# Distance apart:
#
# \[
# |P_1(t) - P_2(t)| = 30
# \]
#
# Substitute in terms of \( t \):
#
# \[
# |60t - (-180 + 90(t - 2))| = 30
# \]
#
# Simplify inside the absolute value:
#
# \[
# |60t + 180 - 90t + 180| = 30
# \]
#
# \[
# |(-30t) + 360| = 30
# \]
#
# Which gives two cases:
#
# 1. \(-30t + 360 = 30\)
# 2. \(-30t + 360 = -30\)
#
# ---
#
# For case 1:
#
# \[
# -30t + 360 = 30 \implies -30t = 30 - 360 = -330 \implies t = \frac{330}{30} = 11
# \]
#
# For case 2:
#
# \[
# -30t + 360 = -30 \implies -30t = -390 \implies t = \frac{390}{30} = 13
# \]
#
# Since \( t \geq 2 \), both times are valid mathematically.
#
# ---
#
# #### Step 2.5: Check feasibility in the context
#
# - At \( t=11 \) hours and \( t=13 \) hours, trains are exactly 30 miles apart.
# - At \( t=11 \), distance between trains becomes 30 miles **first** after the reversal.
# - At \( t=13 \), distance becomes 30 miles **again** (as they continue moving).
#
# ---
#
# ### **Final answers:**
#
# - **Trains 450 miles apart after:** \( \boxed{3 \text{ hours}} \)
# - **Trains 30 miles apart again after reversal at:** \( \boxed{11 \text{ hours}} \) (the first time after reversal)
#
# ---
#
# If you want, I can help you with a graph or further explanations!

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "How can i make AI for learning piano"}]

# Then make the first call:

response = openai.chat.completions.create(  
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

print(business_idea)

question = f"Please propose a pain point for {business_idea}."
messages = [{"role": "user", "content": question}]  

response = openai.chat.completions.create(  
    model="gpt-4.1-mini",
    messages=messages
)

pain_point = response.choices[0].message.content

print(pain_point)

# And repeat!
# Out:
# Creating an AI for learning piano is an exciting project that can range from a simple app that provides feedback on your playing to a sophisticated system that teaches music theory, provides exercises, and evaluates performance in real-time. Here's a high-level roadmap and some ideas on how you can build such a system:
#
# ### 1. Define the Scope and Purpose
# - **Goal:** Do you want the AI to teach beginners basic piano skills, help intermediate players improve, or generate personalized lessons?
# - **Features:** Consider things like:
#   - Sheet music display
#   - Real-time feedback on playing accuracy (notes, timing)
#   - Music theory lessons
#   - Practice exercises and progress tracking
#   - Audio or MIDI input
#
# ### 2. Choose the Input Method
# - **MIDI Keyboard:** Easiest to get precise note information.
# - **Audio Input:** More challenging; requires audio processing to recognize notes.
# - **Virtual Keyboard:** On-screen keyboard inputs for practice without piano.
#
# ### 3. Core Components
#
# #### a) **Sound or MIDI Detection**
# - If using **MIDI**, you get exact note data (note number, velocity, timing).
# - If using **Audio (microphone)**, you need:
#   - Pitch detection algorithms (e.g., YIN, autocorrelation)
#   - Possibly deep learning models trained to transcribe piano notes (Automatic Music Transcription - AMT)
#
# Open-source tools and libraries:
# - **MIDI:** `mido` or `python-rtmidi` libraries for Python
# - **Audio:** Libraries such as `librosa`, or more advanced models like Google's **Onsets and Frames** (a neural network for piano transcription)
#
# #### b) **Sheet Music and Lesson Content**
# - Use **MusicXML** or **ABC notation** files to store lessons or sheet music.
# - Display sheet music using libraries like **VexFlow** (JavaScript) or **music21** (Python)
#
# #### c) **Performance Evaluation**
# - Compare the input notes/timing with the target notes.
# - Highlight wrong notes, missed notes, timing issues.
# - Provide feedback, e.g., suggest practice tips based on common mistakes.
#
# ### 4. Building the AI Model (optional but powerful)
# - Use machine learning to:
#   - Detect and transcribe audio in real-time.
#   - Model student progress and adapt lesson difficulty.
#   - Generate personalized exercises.
# - Techniques include:
#   - Recurrent Neural Networks (RNNs) or Transformers for sequence prediction.
#   - Reinforcement learning to adapt exercises.
# - Existing datasets like MAESTRO can help train models on piano audio and MIDI aligned data.
#
# ### 5. User Interface
# - Desktop app (Python with Tkinter/PyQt)
# - Web app (React/Angular + backend)
# - Mobile app (Flutter, React Native)
#
# ### 6. Example Workflow
#
# For a beginner-friendly AI piano tutor app:
#
# - Display a simple sheet music exercise.
# - Listen to user's playing via MIDI.
# - Detect notes played and their timing.
# - Compare with target notes.
# - Give immediate feedback:
#   - Correct notes hit
#   - Timing accuracy
#   - Suggestions for improvement
#
# ### 7. Tools and Frameworks to Explore
#
# - **Magenta (TensorFlow)**: Open-source research project exploring ML in music.
# - **Onsets and Frames**: Google’s piano transcription model.
# - **FluidSynth**: Software synthesizer for MIDI playback.
# - **Aubio**: Audio analysis library for pitch detection.
# - **music21**: Python toolkit for computational musicology.
#
# ---
#
# ### Simple Starting Point Example (Python + MIDI)
#
# ```python
# import mido
# from mido import MidiFile
#
# # Load a MIDI file of a lesson exercise
# mid = MidiFile('exercise1.mid')
#
# # Suppose you have MIDI input device connected
# for msg in mido.open_input('Your MIDI Keyboard Name'):
#     if msg.type == 'note_on':
#         print(f"Note played: {msg.note}, velocity: {msg.velocity}")
#         # Compare with expected notes from the MIDI lesson file and provide feedback
# ```
#
# ---
#
# ### Next Steps
#
# 1. Choose your input (MIDI or audio).
# 2. Build or integrate note detection.
# 3. Prepare lesson content (exercises, sheet music).
# 4. Implement feedback logic.
# 5. Add UI to display lessons and feedback.
# 6. Optionally, train or fine-tune AI models for transcription or personalization.
#
# ---
#
# If you want, I can help you with any specific part like note detection from audio, MIDI handling, UI suggestions, or even sample code demonstrations. Just ask!
# A key pain point in creating an AI for learning piano is **accurately and robustly detecting user input from audio in real-time, especially in noisy or imperfect environments**.
#
# ### Why this is a pain point:
# - **Audio Input Complexity:** Unlike MIDI, which provides clean, discrete note data, audio input requires complex signal processing or machine learning to transcribe notes accurately.
# - **Real-time Constraints:** The system must detect notes with very low latency to provide instant feedback, which is challenging for computationally expensive models.
# - **Polyphony and Expressiveness:** Piano playing often involves multiple notes at once (chords), varying dynamics, pedal use, and expressive timing — making transcription non-trivial.
# - **Environmental Noise:** Background noise or imperfect microphone quality can degrade detection accuracy.
# - **Model Generalization:** Training AI models robust enough to handle different piano timbres, rooms, and playing styles requires lots of diverse data.
#
# ### Impact
# Without reliable note and timing detection, the AI cannot provide meaningful feedback, frustrating learners and limiting the system's usefulness compared to MIDI-based apps.
#
# ---
#
# If you plan a simple app and can require MIDI input, this pain point shrinks. But for broader accessibility (e.g., learning with an acoustic piano and just a mic), this is a major technical challenge and a crucial area where innovation or compromise is needed.
#
# ---
#
# Would you like help designing a robust note detection pipeline, or exploring trade-offs between MIDI and audio input implementations?
